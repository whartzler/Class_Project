# %%
import pandas as pd

# %%
file = 'EV_Stations.csv'
stations = pd.read_csv(file)
stations.head()
# Out:
# C:\Users\Nick\AppData\Local\Temp\ipykernel_11160\256751366.py:2: DtypeWarning: Columns (6,20,31,46,69) have mixed types. Specify dtype option on import or set low_memory=False.
#   stations = pd.read_csv(file)
#   Fuel Type Code                    Station Name           Street Address  \
# 0           ELEC   Los Angeles Convention Center       1201 S Figueroa St
# 1           ELEC  California Air Resources Board         9530 Telstar Ave
# 2           ELEC          Scripps Green Hospital  10666 N Torrey Pines Rd
# 3           ELEC                   Galpin Motors        15421 Roscoe Blvd
# 4           ELEC               Galleria at Tyler   1299 Galleria at Tyler
#
#               Intersection Directions         City State    ZIP  Plus4  \
# 0            West hall and South hall  Los Angeles    CA  90015    NaN
# 1                                 NaN     El Monte    CA  91731    NaN
# 2  Patient Parking Structure, level G     La Jolla    CA  92037    NaN
# ...

# %%
stations_clean = stations[['Station Name', 'City', 'State', 'ZIP', 'Latitude' , 'Longitude', 'Open Date']]
stations_clean
# Out:
#                                  Station Name           City State    ZIP  \
# 0               Los Angeles Convention Center    Los Angeles    CA  90015
# 1              California Air Resources Board       El Monte    CA  91731
# 2                      Scripps Green Hospital       La Jolla    CA  92037
# 3                               Galpin Motors      Sepulveda    CA  91343
# 4                           Galleria at Tyler      Riverside    CA  92503
# ...                                       ...            ...   ...    ...
# 51532            GEORGIA POWER GAINESVILLE DC    Gainesville    GA  30501
# 51533                    Makaha Beach Cabanas        Waianae    HI  96792
# 51534  RH3C+J3 Marina District (US-7MK-ZS3-3)  San Francisco    CA  94109
# 51535  RH3C+J3 Marina District (US-7MK-ZS3-4)  San Francisco    CA  94109
# 51536  RH3C+J3 Marina District (US-7MK-ZS3-1)  San Francisco    CA  94109
#
#         Latitude   Longitude   Open Date
# ...
