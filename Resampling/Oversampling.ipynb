# %%
import pandas as pd
from sklearn.utils import resample

file = '../Encoding/FCV_Label_Encoded.csv'
df = pd.read_csv(file)

df
# Out:
#       Previous PHEVs  Previous BEVs  Previous HEVs  Previous CNGs  \
# 0                  1              0              0              0
# 1                  0              0              1              0
# 2                  1              0              0              0
# 3                  0              0              0              0
# 4                  1              0              1              0
# ...              ...            ...            ...            ...
# 3499               0              0              1              0
# 3500               0              0              0              0
# 3501               1              1              0              0
# 3502               0              1              1              0
# 3503               0              1              0              0
#
#       Household Income  \
# 0             275000.0
# 1             275000.0
# 2             125000.0
# 3             125000.0
# 4             225000.0
# ...                ...
# ...

# %%
df = df.rename(columns={'FCV, BEV Dummy' : 'Target'})

# %%
df_majority = df[df.Target==1.0]
df_minority = df[df.Target==0.0]

# %%
df_minority_oversampled = resample(df_minority,
                                   replace=True,
                                   n_samples=len(df_majority),
                                   random_state=123)

# %%
df_oversampled = pd.concat([df_majority, df_minority_oversampled])

# %%
df_oversampled['Target'].value_counts()
# Out:
# 1.0    3317
# 0.0    3317
# Name: Target, dtype: int64

# %%
df_oversampled.to_csv('FCV_Oversampled.csv', index=False)
